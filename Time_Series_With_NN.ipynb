# %%
import pandas as pd

# %%
df = pd.read_csv("train_df.csv", index_col = 'id')
test =pd.read_csv('test_df.csv', index_col = 'id')

# %%
df.head()
# Out:
#         att1      att2      att3      att4      att5      att6      att7  \
# id
# 1  -0.731269 -0.331709  0.180212  0.729356  1.226720  1.584864  1.719098
# 2   1.625923  1.174887  0.633557  0.097815 -0.323979 -0.522682 -0.501078
# 3   0.943523  0.928455  0.959547  0.991248  0.996443  0.959983  0.831277
# 4  -0.990329 -1.200994 -1.383529 -1.503270 -1.538072 -1.420004 -1.121234
# 5   1.014455  0.688760  0.372491  0.081209 -0.188529 -0.464427 -0.759484
#
#         att8      att9     att10 ...    att492    att493    att494    att495  \
# id                               ...
# 1   1.622404  1.349615  0.957586 ... -0.226743 -0.314246 -0.465901 -0.688740
# 2  -0.309937 -0.053305  0.074495 ...  0.149040 -0.350204 -0.763172 -1.028119
# 3   0.580112  0.235417 -0.143359 ... -0.473332 -0.332077 -0.246990 -0.230341
# 4  -0.669089 -0.146006  0.340561 ... -1.112609 -0.271551  0.495545  1.105130
# 5  -1.068931 -1.362857 -1.605835 ...  0.661333  0.827912  0.875500  0.809332
#
# ...

# %%
df.shape
# Out:
# (3636, 501)

# %%
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D
from keras.engine.input_layer import Input
from keras.callbacks import TerminateOnNaN
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('y', axis = 1), df.y)

# %%
nn = Sequential()
nn.add(Dense(128,  input_dim=500))
nn.add(Dropout(0.5))
nn.add(Dense(64, activation='relu'))
nn.add(Dropout(0.5))
# nn.add(Input(shape = 500))
# nn.add(Conv1D(32, 3, padding="same", activation="relu", input_shape = X_train.shape))
# nn.add(MaxPooling1D(pool_size=3))
nn.add(Dense(1, activation = 'sigmoid'))
# nn.add(Dense(2, activation='softmax'))
nn.compile(loss='binary_crossentropy', optimizer='Nadam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\User\Programs\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\User\Programs\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = nn.fit(X_train, y_train, batch_size=32, epochs=40, 
                      verbose=2, validation_data=[X_test, y_test])
# Out:
# WARNING:tensorflow:From C:\Users\User\Programs\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2727 samples, validate on 909 samples
# Epoch 1/40
#  - 2s - loss: 1.1109 - acc: 0.5200 - val_loss: 0.6454 - val_acc: 0.6326
# Epoch 2/40
#  - 1s - loss: 0.8821 - acc: 0.5585 - val_loss: 0.6065 - val_acc: 0.6678
# Epoch 3/40
#  - 1s - loss: 0.7431 - acc: 0.5955 - val_loss: 0.5735 - val_acc: 0.7305
# Epoch 4/40
#  - 1s - loss: 0.6600 - acc: 0.6381 - val_loss: 0.5786 - val_acc: 0.7096
# Epoch 5/40
#  - 0s - loss: 0.6454 - acc: 0.6355 - val_loss: 0.5688 - val_acc: 0.7305
# Epoch 6/40
#  - 1s - loss: 0.6120 - acc: 0.6564 - val_loss: 0.5495 - val_acc: 0.7536
# Epoch 7/40
#  - 1s - loss: 0.5884 - acc: 0.6832 - val_loss: 0.5274 - val_acc: 0.7712
# Epoch 8/40
# ...

# %%
pred = nn.predict_proba(test)

# %%
pred2=[]
for i in pred:
    pred2.append(i[0])

# %%
sample = pd.read_csv("SampleSubmission.csv", index_col = 'Id')

# %%
sample.head()
# Out:
#     y
# Id
# 0   0
# 1   0
# 2   0
# 3   0
# 4   0

# %%
sample['y']= pred2

# %%
sample.to_csv("three.csv")

# %%
sample.head()
# Out:
#            y
# Id
# 0   0.999951
# 1   0.483072
# 2   0.763185
# 3   0.842797
# 4   0.742074
